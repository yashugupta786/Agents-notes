# %% [markdown]
# <a href="https://colab.research.google.com/github/yashugupta786/Agents-notes/blob/main/fara2_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Dec  1 14:00:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q "torch>=2.3.0" "transformers>=4.44.0" "vllm>=0.10.0"
# !pip install -q playwright
# !git clone https://github.com/microsoft/fara.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.3/370.3 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.0/355.0 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 61.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 97.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 123.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 8.8 MB/s eta 0:00:00
# ...

# %%
# !playwright install-deps
# !playwright install
# Out:
# Installing dependencies...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,836 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %%
# %cd /content/fara
# !pip install -e .
# Out:
# /content/fara
# Obtaining file:///content/fara
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 9.5 MB/s eta 0:00:00
# ...
#   Building editable for fara (pyproject.toml) ... done
#   Created wheel for fara: filename=fara-0.1.0-py3-none-any.whl size=9324 sha256=96e3fe48abfb4dd2166a20bdb7f8794958ee2f0a8e0929715b91e2f827386d76
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_4n3c6nz/wheels/a8/25/c1/9e5075f254df0d1cb0691a8042fc3856680abd79c7b405b7ac
# Successfully built fara
# ...
#   Attempting uninstall: pyee
#     Found existing installation: pyee 13.0.0
#     Uninstalling pyee-13.0.0:
#       Successfully uninstalled pyee-13.0.0
# ...

# %%
# !vllm --help | head -n 20
# Out:
# 2025-12-01 14:04:29.383371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764597869.629545    4767 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764597869.696430    4767 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764597870.145515    4767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import time, os

# Try to kill any old vllm processes (ignore error if none)
# !pkill -f "vllm" || echo "no existing vllm process"

# Start vLLM in background, log to /content/vllm.log
# !nohup vllm serve "microsoft/Fara-7B" \
    --port 5000 \
    --dtype auto \
    --max-model-len 4096 > /content/vllm.log 2>&1 &

print("Started vLLM server for Fara-7B, giving it time to load...")
time.sleep(90)  # pause inside the cell

print("\nLast 40 lines of /content/vllm.log:\n")
# !tail -n 40 /content/vllm.log
# Out:
# ^C
# Started vLLM server for Fara-7B, giving it time to load...
#
# Last 40 lines of /content/vllm.log:
#
# 2025-12-01 14:05:27.185472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764597927.206480    5071 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764597927.212975    5071 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764597927.230044    5071 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !curl -s http://127.0.0.1:5000/v1/models || echo "curl failed"
# Out:
# curl failed

# %%
# !ps aux | grep vllm
# !tail -n 80 /content/vllm.log
# Out:
# root        5808  0.0  0.0   7376  3524 ?        S    14:07   0:00 /bin/bash -c ps aux | grep vllm
# root        5810  0.0  0.0   6484  2380 ?        S    14:07   0:00 grep vllm
# (EngineCore_DP0 pid=5280)   File "/usr/local/lib/python3.12/dist-packages/vllm/model_executor/models/qwen2.py", line 248, in __init__
# (EngineCore_DP0 pid=5280)     self.mlp = Qwen2MLP(
# (EngineCore_DP0 pid=5280)                ^^^^^^^^^
# (EngineCore_DP0 pid=5280)   File "/usr/local/lib/python3.12/dist-packages/vllm/model_executor/models/qwen2.py", line 84, in __init__
# (EngineCore_DP0 pid=5280)     self.gate_up_proj = MergedColumnParallelLinear(
# (EngineCore_DP0 pid=5280)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore_DP0 pid=5280)   File "/usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/linear.py", line 631, in __init__
# (EngineCore_DP0 pid=5280)     super().__init__(
# ...
